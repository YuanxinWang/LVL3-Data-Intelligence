# %%
# %run ./00_config

# %%
endpoint = "/v1/references/airports"
url = f"{base_url}{endpoint}?limit=100&offset=0"
print(f"sending request: {url}")
response = requests.get(url, headers=headers)
if response.status_code == 200:
    data = response.json()
    airport_resource = data.get("AirportResource", {})
    meta_info = airport_resource.get("Meta", {})
    total_count = meta_info.get("TotalCount", 0)
    print(f"TotalCount: {total_count}")
