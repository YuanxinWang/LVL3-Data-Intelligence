# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# [2026-03-17 18:57:23.463426] Databricks secret fetch failed: default auth: metadata-service: HTTPConnectionPool(host='127.0.0.1', port=38747): Max retries exceeded with url: /5ce6695d-ec68-478c-ab37-51b959e0ae30 (Caused by NewConnectionError("HTTPConnection(host='127.0.0.1', port=38747): Failed to establish a new connection: [Errno 111] Connection refused")). Config: host=https://dbc-6353a6c5-179c.cloud.databricks.com, auth_type=metadata-service, serverless_compute_id=auto, metadata_service_url=***. Env: DATABRICKS_HOST, DATABRICKS_AUTH_TYPE, DATABRICKS_SERVERLESS_COMPUTE_ID, DATABRICKS_METADATA_SERVICE_URL
# [2026-03-17 18:57:23.463540] Config loaded successfully. Proxy password: ****************
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

# Allow Python to look up files in this folder
sys.path.append(os.path.abspath('.'))
import config
import ingestion_flight_status as ingest
target_dates = ingest.get_date_list(config.LOOKBACK_DAYS)
time_slots = ["04:00", "08:00", "12:00", "16:00", "20:00", "00:00"]
for date in target_dates:
    print(f"Processing {date}")
    for slot in time_slots:
        from_datetime = f"{date}T{slot}"
        print(f"\nProcessing {from_datetime}")
        full_url = f"{config.BASE_URL}/v1/operations/flightstatus/arrivals/{config.HUB_AIRPORT}/{from_datetime}"
        ingest.execute_ingestion_flight_status(full_url, 0, config.API_LIMIT, config.HUB_AIRPORT, from_datetime.replace(":", ""))
# Out:
# [2026-03-17 19:10:49.470786] Databricks secret fetch failed: default auth: metadata-service: HTTPConnectionPool(host='127.0.0.1', port=38747): Max retries exceeded with url: /5ce6695d-ec68-478c-ab37-51b959e0ae30 (Caused by NewConnectionError("HTTPConnection(host='127.0.0.1', port=38747): Failed to establish a new connection: [Errno 111] Connection refused")). Config: host=https://dbc-6353a6c5-179c.cloud.databricks.com, auth_type=metadata-service, serverless_compute_id=auto, metadata_service_url=***. Env: DATABRICKS_HOST, DATABRICKS_AUTH_TYPE, DATABRICKS_SERVERLESS_COMPUTE_ID, DATABRICKS_METADATA_SERVICE_URL
# [2026-03-17 19:10:49.470876] Config loaded successfully. Proxy password: ********************
# Processing 2026-03-17
#
# Processing 2026-03-17T04:00
# =======URL: https://lh-proxy.onrender.com/v1/operations/flightstatus/arrivals/FRA/2026-03-17T04:00?limit=100&offset=0=========
# +++++++Header: {'password': 'DataIntelligence2026'}+++++++++
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 16
#      14 print(f"\nProcessing {from_datetime}")
#      15 full_url = f"{config.BASE_URL}/v1/operations/flightstatus/arrivals/{config.HUB_AIRPORT}/{from_datetime}"
# ---> 16 ingest.execute_ingestion_flight_status(full_url, 0, config.API_LIMIT, config.HUB_AIRPORT, from_datetime.replace(":", ""))
#
# File ~/projects/LVL3-Data-Intelligence/ingestion_flight_status.py:50, in execute_ingestion_flight_status(pre_url, offset, limit, airport, date_str)
#      49 def execute_ingestion_flight_status(pre_url, offset, limit, airport, date_str):
# ---> 50     raw_data = single_fetch(pre_url, offset, limit)
#      51     if raw_data is not None:
#      52         save_to_volume(raw_data, airport, date_str, offset, limit)
#
# File ~/projects/LVL3-Data-Intelligence/ingestion_flight_status.py:40, in save_to_volume(raw_json, airport, date_str, offset, limit)
#      38 timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
#      39 filename = f"{airport}_{date_str}_off{offset}_lim{limit}_{timestamp}.json"
# ---> 40 full_path = f"{config.VOLUME_PATH}{filename}"
#      42 with open(full_path, "w", encoding="utf-8") as f:
#      43     json.dump(raw_json, f, ensure_ascii=False, indent=4)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/workspace/lufthansa/raw_data/FRA_2026-03-17T0400_off0_lim100_20260317191052.json'
