# %% [markdown]
# - fetch date should be yesterday not today
# - loop the fetch code for reference data to have a complete version
# - add fetching date to the saved raw data for reference data
# - compare the reference data after fetching: if no change, discard. if any change, create new file and save
# - write read me file : explaining : reference data need to be fetched once a month, so fetching all data doesnt hurt too much in our case. but flight status we currently cannot afford to fetch every flight everyday, so we choose a few representive flights as example.
# - bronze layer requires full data. therefor no pre select in fetching state. all language should be taken.
