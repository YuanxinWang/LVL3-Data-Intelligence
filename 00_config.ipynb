# %%
# Default set up to avoid repeating

# import all needed tools
# for API calls / json parsing / time.sleep / datetime.now
import requests
import json
import time
from datetime import datetime

# set up the API call
base_url = "https://lh-proxy.onrender.com"
password = dbutils.secrets.get(scope = "lh_secrets", key = "proxy_pass")
headers = {"password": password}
volume_path = "/Volumes/workspace/lufthansa/raw_data/"

# successful message print
print("Config set up successfully")
